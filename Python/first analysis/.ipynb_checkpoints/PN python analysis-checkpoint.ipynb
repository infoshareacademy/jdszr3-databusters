# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_pn = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv") #zaimportowanie pliku z danymi

df_pn
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_pn = df[["Attrition", "OverTime", "PercentSalaryHike",
       "PerformanceRating", "TotalWorkingYears" ]] # Attrition oraz wybrane dane

df_pn
# Out:
#      Attrition OverTime  PercentSalaryHike  PerformanceRating  \
# 0          Yes      Yes                 11                  3
# 1           No       No                 23                  4
# 2          Yes      Yes                 15                  3
# 3           No      Yes                 11                  3
# 4           No       No                 12                  3
# ...        ...      ...                ...                ...
# 1465        No       No                 17                  3
# 1466        No       No                 15                  3
# 1467        No      Yes                 20                  4
# 1468        No       No                 14                  3
# 1469        No       No                 12                  3
#
#       TotalWorkingYears
# 0                     8
# 1                    10
# 2                     7
# 3                     8
# 4                     6
# ...                 ...
# 1465                 17
# ...

# %%
df_pn.describe() # podstawowe funkcje
# Out:
#        PercentSalaryHike  PerformanceRating  TotalWorkingYears
# count        1470.000000        1470.000000        1470.000000
# mean           15.209524           3.153741          11.279592
# std             3.659938           0.360824           7.780782
# min            11.000000           3.000000           0.000000
# 25%            12.000000           3.000000           6.000000
# 50%            14.000000           3.000000          10.000000
# 75%            18.000000           3.000000          15.000000
# max            25.000000           4.000000          40.000000

# %%
df_pn.info() # liczba rekordów oraz typ danych
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Attrition          1470 non-null   object
#  1   OverTime           1470 non-null   object
#  2   PercentSalaryHike  1470 non-null   int64
#  3   PerformanceRating  1470 non-null   int64
#  4   TotalWorkingYears  1470 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 57.5+ KB

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_pn.corr(),annot=True)
#[DS] Korelacje wszystkiego ze wszystkim.
# Out:
# <AxesSubplot:>

# %%
df_pn['Attrition'] = df_pn['Attrition'].apply(lambda x:1 if x == 'Yes' else 0)
# Out:
# <ipython-input-79-1ca58d3d80e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pn['Attrition'] = df_pn['Attrition'].apply(lambda x:1 if x == 'Yes' else 0)

# %%
df_pn
# Out:
#       Attrition OverTime  PercentSalaryHike  PerformanceRating  \
# 0             1      Yes                 11                  3
# 1             0       No                 23                  4
# 2             1      Yes                 15                  3
# 3             0      Yes                 11                  3
# 4             0       No                 12                  3
# ...         ...      ...                ...                ...
# 1465          0       No                 17                  3
# 1466          0       No                 15                  3
# 1467          0      Yes                 20                  4
# 1468          0       No                 14                  3
# 1469          0       No                 12                  3
#
#       TotalWorkingYears
# 0                     8
# 1                    10
# 2                     7
# 3                     8
# 4                     6
# ...                 ...
# 1465                 17
# ...

# %%
# How many employees left the company
left_df = df_pn[df_pn['Attrition'] == 1]
# How many employees stayed in the company
stayed_df = df_pn[df_pn['Attrition'] == 0]

# %%
print(len(df_pn))
print(len(left_df))
print(len(stayed_df))
# Out:
# 1470
# 237
# 1233

# %%
left_df.describe()
# Out:
#        Attrition  PercentSalaryHike  PerformanceRating  TotalWorkingYears
# count      237.0         237.000000         237.000000         237.000000
# mean         1.0          15.097046           3.156118           8.244726
# std          0.0           3.770294           0.363735           7.169204
# min          1.0          11.000000           3.000000           0.000000
# 25%          1.0          12.000000           3.000000           3.000000
# 50%          1.0          14.000000           3.000000           7.000000
# 75%          1.0          17.000000           3.000000          10.000000
# max          1.0          25.000000           4.000000          40.000000

# %%
stayed_df.describe()
# Out:
#        Attrition  PercentSalaryHike  PerformanceRating  TotalWorkingYears
# count     1233.0        1233.000000        1233.000000        1233.000000
# mean         0.0          15.231144           3.153285          11.862936
# std          0.0           3.639511           0.360408           7.760719
# min          0.0          11.000000           3.000000           0.000000
# 25%          0.0          12.000000           3.000000           6.000000
# 50%          0.0          14.000000           3.000000          10.000000
# 75%          0.0          18.000000           3.000000          16.000000
# max          0.0          25.000000           4.000000          38.000000

# %%
plt.figure(figsize = (7,7))
sns.countplot(x = 'OverTime', hue = 'Attrition', data = df_pn)
pass

# %%
plt.figure(figsize = (7,7))
sns.countplot(x = 'PercentSalaryHike', hue = 'Attrition', data = df_pn)
pass

# %%
plt.figure(figsize = (7,7))
sns.countplot(x = 'PerformanceRating', hue = 'Attrition', data = df_pn)
pass

# %%
plt.figure(figsize = (15,15))
sns.countplot(x = 'TotalWorkingYears', hue = 'Attrition', data = df_pn)
pass

# %%
plt.figure(figsize = (15,8))

sns.kdeplot(left_df['PercentSalaryHike'], label = 'Employess who left', shade = True, color = 'r')
sns.kdeplot(stayed_df['PercentSalaryHike'], label = 'Employess who stayed', shade = True, color = 'g')
pass

# %%
plt.figure(figsize = (15,8))

sns.kdeplot(left_df['PerformanceRating'], label = 'Employess who left', shade = True, color = 'r')
sns.kdeplot(stayed_df['PerformanceRating'], label = 'Employess who stayed', shade = True, color = 'g')
pass

# %%
plt.figure(figsize = (15,8))

sns.kdeplot(left_df['TotalWorkingYears'], label = 'Employess who left', shade = True, color = 'r')
sns.kdeplot(stayed_df['TotalWorkingYears'], label = 'Employess who stayed', shade = True, color = 'g')
pass

# %%
plt.figure(figsize = (15,10))
sns.boxplot(x = 'TotalWorkingYears', y = 'PercentSalaryHike', data = df_pn)
pass
